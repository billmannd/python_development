# %%
import numpy as np

# %%
nl = np.random.randint(100,size=100)

# %%
#first value
f = 0
#second value
s = 0
nextItem=True

# %%
for j in range(0,len(nl)):
    if j!=len(nl) and i!=len(nl):
        for i in range(0,len(nl)-j):
            if nl[i]<nl[i-1]:
                s=nl[i-1]
                nl[i-1]=nl[i]
                nl[i]=s
                print(nl[i-1],nl[i])
# Out:
# 4 97
# 5 97
# 5 97
# 6 97
# 7 97
# 7 97
# 9 97
# 11 97
# 13 97
# 13 97
# 14 97
# 17 97
# 17 97
# 17 97
# 18 97
# 18 97
# 24 97
# 24 97
# 24 97
# 26 97
# 26 97
# 27 97
# 27 97
# 27 97
# 28 97
# 28 97
# 28 97
# 29 97
# 31 97
# 32 97
# 33 97
# 34 97
# 34 97
# 35 97
# 36 97
# 36 97
# 38 97
# 38 97
# 39 97
# 39 97
# 40 97
# 40 97
# 41 97
# 43 97
# 43 97
# 45 97
# 45 97
# 47 97
# 48 97
# 49 97
# 50 97
# 50 97
# 51 97
# 52 97
# 53 97
# 54 97
# 56 97
# 58 97
# 59 97
# 60 97
# 61 97
# 62 97
# 62 97
# 63 97
# 66 97
# 68 97
# 69 97
# 70 97
# 71 97
# 71 97
# 72 97
# 75 97
# 75 97
# 76 97
# 76 97
# 77 97
# 77 97
# 79 97
# 79 97
# 80 97
# 80 97
# 81 97
# 81 97
# 83 97
# 87 97
# 88 97
# 89 97
# 90 97
# 90 97
# 91 97
# 91 97
# 91 97
# 91 97
# 92 97
# 92 97
# 92 97
# 93 97
# 96 97
# 96 97
# 4 97
# 4 96
# 4 96
# 4 93
# 4 92
# 4 92
# 4 92
# 4 91
# 4 91
# 4 91
# 4 91
# 4 90
# 4 90
# 4 89
# 4 88
# 4 87
# 4 83
# 4 81
# 4 81
# 4 80
# 4 80
# 4 79
# 4 79
# 4 77
# 4 77
# 4 76
# 4 76
# 4 75
# 4 75
# 4 72
# ...
